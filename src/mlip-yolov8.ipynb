# %%
# !nvidia-smi
# Out:
# Thu May  9 09:45:51 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# ### Removing Noise from the image

# %%
# import numpy as np
# denoised_images = []
# for img in images:
#     img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#     denoised_img_rgb = cv2.fastNlMeansDenoisingColored(img_rgb, None, 10, 10, 7, 21)
#     denoised_img_bgr = cv2.cvtColor(denoised_img_rgb, cv2.COLOR_RGB2BGR)
#     denoised_images.append(denoised_img_bgr)

# %% [markdown]
# ## Code to visualise image after removal of salt and peeper noise.

# %%
# import matplotlib.pyplot as plt

# # Assuming `denoised_images` is a list containing denoised images

# # Check if denoised images list is not empty
# if denoised_images:
#     # Get the first denoised image
#     first_denoised_img = denoised_images[1]
#     print(first_denoised_img)

# #     # Display the first denoised image using Matplotlib
# #     plt.imshow(cv2.cvtColor(first_denoised_img, cv2.COLOR_BGR2RGB))
# #     plt.title('First Denoised Image')
# #     plt.axis('off')  # Turn off axis
# #     plt.show()
# # else:
# #     print("No denoised images found.")

# %% [markdown]
# # Yolov8

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 kB 23.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import ultralytics

# %%
from ultralytics import YOLO
model = YOLO('yolov8n-cls.pt') 
data_path='/kaggle/input/god-dataset/God-dataset'
import os

# Print the contents of the dataset directory
print(os.listdir(data_path))
results = model.train(data=data_path, epochs=20, imgsz=640)
# Out:
# ...
# 100%|██████████| 5.30M/5.30M [00:00<00:00, 11.6MB/s]
# ['validation', 'train']
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO('/kaggle/input/best-last/best.pt')
metrics = model.val()  
metrics.top1  
metrics.top5
# Out:
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1450252 parameters, 0 gradients, 3.3 GFLOPs
#
# Dataset not found ⚠️, missing path /media/iit-12/DATA/vehicle_dataset, attempting download...
# ...
# ⚠️ Download failure, retrying 1/3 https://github.com/ultralytics/yolov5/releases/download/v1.0//media/iit-12/DATA/vehicle_dataset.zip...
# Dataset download success ✅ (0.4s), saved to /media/iit-12/DATA/vehicle_dataset
#
# WARNING ⚠️ Dataset 'split=val' not found, using 'split=test' instead.
# ######################################################################## 100.0%
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 model = YOLO('/kaggle/input/best-last/best.pt')
# ----> 2 metrics = model.val()
#       3 metrics.top1
#       4 metrics.top5
#
# ...
